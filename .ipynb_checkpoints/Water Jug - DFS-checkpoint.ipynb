# %% [markdown]
# # Water Jug - DFS

# %%
class State:
    def __init__(self, x, y, Id, parent, children, case):
        self.x = x
        self.y = y
        self.id = Id
        self.parent = parent
        self.children = children
        self.case = case
    def fillX(self):
        self.x = jug_1_max_cap
    def fillY(self):
        self.y = jug_2_max_cap
    def fillXFromY(self):
        if(self.y>=jug_1_max_cap-self.x):
            self.y = self.y - (jug_1_max_cap-self.x)
            self.x = jug_1_max_cap
        else:
            self.x = self.x + self.y
            self.y = 0
    def fillYFromX(self):
        if(self.x>=jug_2_max_cap-self.y):
            self.x = self.x - (jug_2_max_cap-self.y)
            self.y = jug_2_max_cap
        else:
            self.y = self.y + self.x
            self.x = 0
    def EmptyX(self):
        self.x = 0
    def EmptyY(self):
        self.y = 0
    def hasReachedFinal(self):
        if(self.x==jug_1_final_cap and self.y==jug_2_final_cap):
            return True
        return False

def printTree(tree):
    for i in tree:
        print(str(i) + " : " + str(tree[i].x) + " " + str(tree[i].y) + " " + str(tree[i].parent) + " " + str(tree[i].children) + " " + str(tree[i].case))
        print()

# %%
tree = {}
s = 0
root = State(0,0,s,None,[],0)
tree[s] = root
printTree(tree)
s += 1
parent = 0
# Out:
# 0 : 0 0 None [] 0

# %%
jug_1_max_cap = 3
jug_2_max_cap = 4
jug_1_final_cap = 0
jug_2_final_cap = 2


while(parent != None):
    
    newNode = State(tree[parent].x, tree[parent].y, s, parent,[], 0)
    if(tree[parent].case < 1):
        tree[parent].case += 1
        if(newNode.y != jug_2_max_cap):
            newNode.fillY()
            path = []
            p = newNode.parent
            while(p!=None):
                path.append([tree[p].x,tree[p].y])
                p = tree[p].parent
            if([newNode.x, newNode.y] not in path):
                tree[parent].children.append(s)
                tree[s] = newNode
                parent = s
                s += 1
                if(newNode.hasReachedFinal()):
                    break   
                continue
    printTree(tree)
    
    newNode = State(tree[parent].x, tree[parent].y, s, parent,[], 0)
    if(tree[parent].case < 2):
        tree[parent].case += 1
        if(newNode.x != jug_1_max_cap):
            newNode.fillX()
            path = []
            p = newNode.parent
            while(p!=None):
                path.append([tree[p].x,tree[p].y])
                p = tree[p].parent
            if([newNode.x, newNode.y] not in path):
                tree[parent].children.append(s)
                tree[s] = newNode
                parent = s
                s += 1
                if(newNode.hasReachedFinal()):
                    break   
                continue
    printTree(tree)
    
    newNode = State(tree[parent].x,tree[parent].y,s,parent,[],0)
    if(tree[parent].case < 3):
        tree[parent].case += 1
        if(newNode.y != 0):
            newNode.EmptyY()
            path = []
            p = newNode.parent
            while(p!=None):
                path.append([tree[p].x,tree[p].y])
                p = tree[p].parent
            if([newNode.x, newNode.y] not in path):
                tree[parent].children.append(s)
                tree[s] = newNode
                parent = s
                s += 1
                if(newNode.hasReachedFinal()):
                    break   
                continue
    printTree(tree)
    
    newNode = State(tree[parent].x,tree[parent].y,s,parent,[],0)
    if(tree[parent].case < 4):
        tree[parent].case += 1
        if(newNode.x != 0):
            newNode.EmptyX()
            path = []
            p = newNode.parent
            while(p!=None):
                path.append([tree[p].x,tree[p].y])
                p = tree[p].parent
            if([newNode.x, newNode.y] not in path):
                tree[parent].children.append(s)
                tree[s] = newNode
                parent = s
                s += 1
                if(newNode.hasReachedFinal()):
                    break   
                continue
    printTree(tree)
    
    newNode = State(tree[parent].x,tree[parent].y,s,parent,[],0)
    if(tree[parent].case < 5):
        tree[parent].case += 1
        if(newNode.x != 0 and newNode.y!=jug_2_max_cap):
            newNode.fillYFromX()
            path = []
            p = newNode.parent
            while(p!=None):
                path.append([tree[p].x,tree[p].y])
                p = tree[p].parent
            if([newNode.x, newNode.y] not in path):
                tree[parent].children.append(s)
                tree[s] = newNode
                parent = s
                s += 1
                if(newNode.hasReachedFinal()):
                    break   
                continue
    printTree(tree)
    
    newNode = State(tree[parent].x,tre
        tree[parent].case += 1
        if(newNode.y != 0 and newNode.x!=jug_1_max_cap):
            newNode.fillXFromY()
            path = []
            p = newNode.parent
            while(p!=None):
                path.append([tree[p].x,tree[p].y])
                p = tree[p].parent
            if([newNode.x, newNode.y] not in path):
                tree[parent].children.append(s)
                tree[s] = newNode
                parent = s
                s += 1
                if(newNode.hasReachedFinal()):
                    break   
                continue
    printTree(tree)
    
    parent = tree[parent].parent
# Out:
# 1
# yes
# 1
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [] 1
#
# 2
# yes
# 1
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [] 1
#
# 2
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [] 2
#
# 3
# yes
# 1
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [] 1
#
# 2
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [] 2
#
# 3
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [] 3
#
# 4
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [] 4
#
# 5
# yes
# 1
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [] 1
#
# 2
# yes
# 1
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [] 1
#
# 2
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [] 2
#
# 3
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [] 3
#
# 4
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [] 4
#
# 5
# yes
# 1
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [6] 5
#
# 6 : 2 4 5 [] 1
#
# 2
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [6] 5
#
# 6 : 2 4 5 [] 2
#
# 3
# yes
# 1
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [6] 5
#
# 6 : 2 4 5 [7] 3
#
# 7 : 2 0 6 [] 1
#
# 2
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [6] 5
#
# 6 : 2 4 5 [7] 3
#
# 7 : 2 0 6 [] 2
#
# 3
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [6] 5
#
# 6 : 2 4 5 [7] 3
#
# 7 : 2 0 6 [] 3
#
# 4
# yes
# 0 : 0 0 None [1] 1
#
# 1 : 0 4 0 [2] 2
#
# 2 : 3 4 1 [3] 3
#
# 3 : 3 0 2 [4] 5
#
# 4 : 0 3 3 [5] 2
#
# 5 : 3 3 4 [6] 5
#
# 6 : 2 4 5 [7] 3
#
# 7 : 2 0 6 [] 4
#
# 5
# yes

# %%
s = len(tree)-1
result = []
while(s!=None):  
    result.append([tree[s].x, tree[s].y])
    s = tree[s].parent
for j in reversed(result):
    print(j, end =" ")
# Out:
# [0, 0]

# %%
tree
# Out:
# {0: <__main__.State at 0x176d25f0b80>}

# %%
# Out:
# 0 : 0 0 None [] 0
